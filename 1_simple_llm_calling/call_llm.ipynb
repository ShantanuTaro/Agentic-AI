# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()
# Out:
# True

# %%
llm = ChatGoogleGenerativeAI(model='gemma-4-31b-it')
response = llm.invoke("How many moons does Jupiter have?")
print(response.text)
# Out:
# Jupiter has **95 officially recognized moons**.
#
# This number can change as astronomers discover new, smaller moons orbiting the planet. The most famous are the four large **Galilean moons**, discovered by Galileo Galilei in 1610: **Io, Europa, Ganymede, and Callisto**.

# %%
response = llm.invoke(
    [
        ["system","You are a helpful assistant that answers in short one line"],
        ["human","How many moons does Jupiter have?"]
    ]
)
print(response.text)
# Out:
# Jupiter has 95 moons.

# %%
prompt = "Write a single tagline for quirky coffee shop. Only output tagline"
llm = ChatGoogleGenerativeAI(model='gemini-2.5-flash', temperature=1)

response = llm.invoke(prompt)
print(response.text)
# Out:
# Uncommon Grounds.

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(model="qwen/qwen3-32b",     reasoning_format="parsed")

# %%
messages = [
    (
        "system",
        "You are a helpful assistant that translates English to French. Translate the user sentence.",
    ),
    ("human", "Hello"),
]
ai_msg = llm.invoke(messages)
print(ai_msg.content)
# Out:
# Bonjour
